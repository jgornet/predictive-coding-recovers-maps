# %%
# %cd /content

# download the predictive coding repository
# !git clone https://github.com/jgornet/predictive-coding-recovers-maps.git
# %cd predictive-coding-recovers-maps/notebooks
# !pip install -r ../requirements.txt

# %%
from predictive_coding.analysis import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
latents = np.load('../weights/predictive-coder-environment-latents.npy')
positions = np.load('../weights/predictive-coder-environment-positions.npy')[:, :2]

# %%
latents = Latents(latents, positions)

# %%
fields = PlaceFields(latents)

# %%
fig = fields_plot(fields)
fig.set_size_inches((10, 20))
plt.show()

# %%
fields_histogram(fields)
plt.show()

# %%
fields_per_position(fields)
plt.show()

# %%
positions_per_field(fields)
plt.show()

# %%
decoder = PlaceFieldDecoder(fields)
decoder.fit()
# Out:
# LinearRegression()

# %%
distance_histogram(decoder)
plt.show()

# %%
distance_regression(decoder)
plt.show()

# %%
direction_histogram(decoder)
plt.show()

# %%
direction_regression(decoder)
plt.show()
